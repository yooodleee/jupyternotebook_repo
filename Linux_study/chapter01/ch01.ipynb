# %% [markdown]
# ## **chapter01. 리눅스 첫 걸음**

# %% [markdown]
# ### **1.1. 리눅스란?**
# ---

# %% [markdown]
# 리눅스는 윈도우, 맥과 같이 운영체제에 속한다.
# 즉, 컴퓨터라는 하드웨어에서 다양한 애플리케이션을 돌리기 위한 기본 소프트웨어이다.
# 하지만 리눅스는 일반적인 데스크톱뿐 아니라 임베디드, 서버 등 다양한 분야에서 널리 사용되고 있다.

# %% [markdown]
# 이 장에서는 리눅스의 특징을 비롯한 기초 지식에 대해 알아보겠다.

# %% [markdown]
# #### **리눅스의 장점**

# %% [markdown]
# 리눅스는 다음과 같은 특징이 있으며 특히 서버용 운영 체제로 많이 사용된다.

# %% [markdown]
# * 오픈 소스로, 누구나 자유롭고 무료로 사용할 수 있다.
# * 높은 품질의 다양한 소프트웨어를 리눅스에서 돌릴 수 있다(아파치 hmp 서버나 MySQL 데이터베이스 등).
# * 전 세계에서 많이 사용되고 있는 만큼 신뢰성이 높다.
# * 스크립트를 통해 많은 부분을 자동화할 수 있어 운영에 편리하다.

# %% [markdown]
# 우리가 평소에 자주 사용하는 웹 서비스들도 대부분 리눅스에서 돌아가고 있다.
# 브라우저에서 요청을 받아들이는 웹 서버, 비즈니스 로직을 수행하는 애플리케이션 서버, 데이터를 저장하는 데이터 베이스의 운영 체제로 리눅스를 사용하는 것이 일반적이기 때문이다.
# 따라서 IT 엔지니어라면 필수적으로 리눅스를 다룰 줄 알아야 하며 컴퓨터를 공부하는 학생들이라면 일찍이 리눅스에 친숙해지는 것이 좋다.
# 또한, 리눅스는 다음과 같은 이유로 프로그래밍 학습 환경으로도 많이 사용된다.

# %% [markdown]
# * 개발 환경 구축이 용이하며 비용이 발생하지 않는다.
# * 오픈 소스여서 운영 체제의 내부 동작을 확인할 수 있다.

# %% [markdown]
# 리눅스는 오픈 소스라 컴퓨터를 깊게 공부하기에 좋다.
# 그런데 일반적으로 많이 사용되는 윈도우에서는 소스 코드가 공개되어 있지 않아 메모리 관리나 네트워크와 관련한 내부 동작을 파악하는 데 한계가 있다.
# 하지만 리눅스는 직접 소스 코드를 보면서 구체적인 동작을 확인할 수 있다.
# 그리고 코드를 수정하면서 다양한 실험을 할 수 있다는 것도 리눅스의 커다란 매력이다.

# %% [markdown]
# #### **리눅스의 단점**

# %% [markdown]
# 리눅스도 단점이 있다.
# 리눅스는 윈도우나 맥보다 상용 애플리케이션이 많지 않다.
# 특히 마이크로소프트의 워드나 엑셀 파일을 편집하려면 리브레오피스(LibreOffice)같은 프로그램을 사용해야 한다.
# 또한, 이미지, 음악, 영상 등 멀티미디어를 편집하는 소프트웨어도 부족하다.

# %% [markdown]
# 그리고 한글 대응이 부족한 것도 리눅스의 단점이다.

# %% [markdown]
# * 공식 문서나 도움말이 영어로만 되어 있을 수 있다.
# * 소프트웨어에 따라 한글 문자가 깨지기도 한다.

# %% [markdown]
# 리눅스가 영어권에서 만들어졌기 때문에 영어는 피할 수 없다.
# 그나마 다행인 것은 공식 문서나 도움말에 어려운 영어가 사용되지 않아서 높은 수준의 영어 실력이 필요하지는 않다는 점이다.
# 다만 영어로 된 문서를 읽는 것이 부담되지 않도록 익숙해져야 한다.

# %% [markdown]
# ### **1.2. 리눅스 환경 준비**
# ---

# %% [markdown]
# #### **배포판이란**

# %% [markdown]
# 리눅스 환경을 준비하기에 앞서 먼저 어떤 배포판을 사용할지 정해야 한다.

# %% [markdown]
# 지금까지 리눅스란 용어를 사용했는데 원래 리눅스란 리눅스 커널만을 의미하는 용어다.
# 커널이란 운영 체제의 중심에서 하드웨어를 제어하는 역할을 담당하는 소프트웨어를 말하며 사용자가 사용하는 도구나 애플리케이션은 포함되지 않는다.

# %% [markdown]
# 이러한 리눅스 커널과 함께 기본적인 명령어와 애플리케이션을 묶어서 사용자가 바로 사용할 수 있게 패키징한 것이 넓은 의미의 리눅스이다.
# 그리고 이것이 바로 리눅스 배포한이다.

# %% [markdown]
# 현재 일반적으로 리눅스라고 하면 넓은 의미의 리눅스를 의미하며, 여기서도 같은 의미로 사용하겠다.
# 그리고 커널을 가리킬 때는 '리눅스 커널'이라고 명시적으로 표현하겠다.

# %% [markdown]
# 리눅스 배포판은 무척 다양한데, 대표적으로 레드햇(Red Hat) 계열과 데비안(Debian) 계열이 있다.

# %% [markdown]
# * 레드햇(Red Hat) 계열: Red Hat Enterprise Linux, CentOS, Fedora
# * 데비안(Debian) 계열: Debian GNU/Linux, Ubuntu

# %% [markdown]
# 특히, 우분투는 편의성이 좋아 인기가 무척 많은 배포판이다.

# %% [markdown]
# #### **가상화 소프트웨어 위의 리눅스 환경**

# %% [markdown]
# 리눅스를 익히려면 실습을 하면서 그 동작을 확인해 보아야 한다.

# %% [markdown]
# 리눅스를 설치하는 첫 번째 방법은 리눅스를 컴퓨터에 직접 설치하는 것이다.
# 이를테면 윈도우가 설치된 컴퓨터의 하드 디스크를 분리하여 리눅스를 추가로 설치하는 것이다.
# 그런데 이는 간단한 작업이 아니며 자칫 잘못하면 현재 환경이 망가질 수도 있다.
# 따라서 여기서는 가상화 소프트웨어를 사용해 컴퓨터에 가상 컴퓨터, 즉 가상 머신에 리눅스 환경을 구축해 보겠다.

# %% [markdown]
# 가상화 소프트웨어를 돌리는 OS를 호스트 OS, 가상화 소프트웨어에 의해 만들어진 가상의 OS를 게스트 OS라고 한다.
# 가상화 소프트웨어를 사용하면 게스트 OS를 재설치하거나 복사하는 것이 무척 간단하다.
# 리눅스를 공부하다 보면 익숙치 않아 종종 실수를 하므로 처음부터 새로 다시 시작하고 싶을 때가 많다.
# 이때 가상화 소프트웨어를 사용하고 있다면 쉽게 재시작할 수 있다.

# %% [markdown]
# 가상화 소프트웨어 중에서는 오라클이 제공하는 오라클 VM 버추얼박스(Oracle VM VirtualBox)가 유명하다.
# 오픈 소스로 무료로 사용할 수 있으며 윈도우나 맥OS에서도 잘 작동한다.
